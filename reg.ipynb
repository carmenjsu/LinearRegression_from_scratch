# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
x, y = datasets.make_regression(n_samples=100,n_features=1, noise=2, random_state=4)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1234)

# %%
fig = plt.figure(figsize=(8, 6))
plt.scatter(x[:, 0],y,color = "b", marker = "o", s = 30)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (80, 1)
# (80,)

# %%
from CSuML import LinearRegre

# %%
regressor = LinearRegre(a=0.001, n_iters=10000)

# %%
regressor.fit(x_train,y_train)
predicted = regressor.predict(x_test)

# %%
def mse(y_actual, y_predicted):
    return np.mean((y_actual-y_predicted)**2)

# %%
mse_val = mse(y_test, predicted)
mse_val
# Out:
# 3.0577089199698237

# %%
y_pred_line = regressor.predict(x)
cmap = plt.get_cmap('Blues')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(x_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(x_test, y_test, color=cmap(0.9), s=10)
plt.plot(x, y_pred_line, color='black', linewidth=2, label="Prediction")

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
